# %% [markdown]
# <a href="https://colab.research.google.com/github/ValenteGabriel/Curso-Python/blob/main/M%C3%A9dia_da_turma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("=== Média da Turma ===")

notas = []

quantidade = int(input("Quantos alunos há na turma? "))

for i in range(quantidade):
    nota = float(input(f"Digite a nota do aluno {i+1}: "))
    notas.append(nota)

soma = sum(notas)
media = soma / quantidade

print("Média da turma:", round(media, 2))
print("Maior nota:", max(notas))
print("Menor nota:", min(notas))

acima_media = 0

for nota in notas:
    if nota > media:
        acima_media += 1

print("Quantidade de alunos acima da média:", acima_media)
