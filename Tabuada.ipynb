# %% [markdown]
# <a href="https://colab.research.google.com/github/ValenteGabriel/Curso-Python/blob/main/Tabuada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("=== Tabuada ===")

numero = int(input("Digite um número inteiro: "))

for i in range(1, 11):
    resultado = numero * i
    print(numero, "x", i, "=", resultado)
# Out:
# === Tabuada ===
# Digite um número inteiro: 9
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90
